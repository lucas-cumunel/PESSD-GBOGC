# %% [markdown]
# DL data (transcriptions)

# %%
import gdown
import zipfile
import os

#download url
url = "lien à mettre"
gdown.download_folder(url, quiet=False)


#Unzipping
folder_path = "./data"

for file in os.listdir(folder_path):
    if file.endswith(".zip"):
        zip_path = os.path.join(folder_path, file)
        extract_path = os.path.join(folder_path, file.replace(".zip", ""))

        print(f"Unzipping: {file} → {extract_path}")

        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_path)
# Out:
# Requirement already satisfied: gdown in /opt/python/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /opt/python/lib/python3.13/site-packages (from gdown->-r requirements.txt (line 1)) (4.14.2)
# Requirement already satisfied: filelock in /opt/python/lib/python3.13/site-packages (from gdown->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: requests[socks] in /opt/python/lib/python3.13/site-packages (from gdown->-r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: tqdm in /opt/python/lib/python3.13/site-packages (from gdown->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4->gdown->-r requirements.txt (line 1)) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4->gdown->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests[socks]->gdown->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests[socks]->gdown->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/python/lib/python3.13/site-packages (from requests[socks]->gdown->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/lib/python3.13/site-packages (from requests[socks]->gdown->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/python/lib/python3.13/site-packages (from requests[socks]->gdown->-r requirements.txt (line 1)) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
