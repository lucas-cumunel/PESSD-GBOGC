# %% [markdown]
# DL data (transcriptions)

# %%
# %pip install gdown
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [gdown]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown
import zipfile
import os

#download url
url = "https://drive.google.com/drive/folders/1A6VoFD7JCXkIKGAYqoLMUcMlRwMkvi3c?usp=sharing"
gdown.download_folder(url, output="data", quiet=False)
# Out:
# Retrieving folder contents
# Retrieving folder 1tOzHFVLRcGY3kup2V0cCVc-HdgOLeet2 biath
# Processing file 1anmr4QorNrI-tsOLVpO3NcP6JI6JsdxP BAH_wav_transcription.csv
# Processing file 15CoI_2hCp69XDujLCtWt80BIhg9xtNLA BAP_wav_transcription.csv
# Processing file 1pEK9cy6tK9ya0c1oTN1I1jPNzCxEJGGx BFR_wav_transcription.csv
# Processing file 1Cne8MVJhblHcCO3SAZ1VYn9XYQZjU65W BH_wav_transcription.csv
# Processing file 1jg6bTsh8AusKUTRWqFqsYE9syHeXrzFo BHR_wav_transcription.csv
# Processing file 1W1eZMDa4gBbLP8nt2dnxzOLEbjFZ5Dz3 BI_wav_transcription.csv
# Processing file 1lMkebCqRpPCU0PyXKZoMgRJ2e1iAvARi BIF_wav_transcription.csv
# Processing file 1I4GKo4oBKR-MeNKEmSq6d9OBRAxVbBEi BIR1_wav_transcription.csv
# Processing file 1ZHdsMC0HbWR-L39DUwSSxbORWyRQoz8Z BIR2_wav_transcription.csv
# Processing file 1Vir31Qu4ERJj1HHXOp4ceEVtEJli19hM BMF_wav_transcription.csv
# Processing file 1Hdzsvjv-UfSp70vMG-IbnSCIXT9on3if BMH_wav_transcription.csv
# ...

# %%
with open("file.zip", "rb") as f:
    print(f.read(10))
# Out:
# b'<!DOCTYPE '

# %%
import requests

response = requests.get(url)

with open("file.zip", "wb") as f:
    f.write(response.content)
